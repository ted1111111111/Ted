# %%
import sys
# !{sys.executable} -m pip install pandas

# %%
import pandas as pddf.head(4)

# %%
df = pd.read_csv("data/Film.csv")

# %%
df.shape
# Out:
# (5268, 13)

# %%
df
# Out:
#             Date   Time                                           Location  \
# 0     09/17/1908  17:18                                Fort Myer, Virginia
# 1     07/12/1912  06:30                            AtlantiCity, New Jersey
# 2     08/06/1913    NaN                 Victoria, British Columbia, Canada
# 3     09/09/1913  18:30                                 Over the North Sea
# 4     10/17/1913  10:30                         Near Johannisthal, Germany
# ...          ...    ...                                                ...
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# ...

# %%
df.head(4)
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
#
#                                              Summary
# ...

# %%
df.dtypes
# Out:
# Date             object
# Time             object
# Location         object
# Operator         object
# Flight #         object
# Route            object
# Type             object
# Registration     object
# cn/In            object
# Aboard          float64
# Fatalities      float64
# Ground          float64
# Summary          object
# dtype: object

# %%
df = pd.read_csv("data/Film.csv", parse_dates=["Date"])

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# Time                    object
# Location                object
# Operator                object
# Flight #                object
# Route                   object
# Type                    object
# Registration            object
# cn/In                   object
# Aboard                 float64
# Fatalities             float64
# Ground                 float64
# Summary                 object
# dtype: object

# %%
df.describe()
# Out:
#             Aboard   Fatalities       Ground
# count  5246.000000  5256.000000  5246.000000
# mean     27.554518    20.068303     1.608845
# std      43.076711    33.199952    53.987827
# min       0.000000     0.000000     0.000000
# 25%       5.000000     3.000000     0.000000
# 50%      13.000000     9.000000     0.000000
# 75%      30.000000    23.000000     0.000000
# max     644.000000   583.000000  2750.000000

# %%
df.describe(include = "all")
# Out:
# C:\Users\soperde\AppData\Local\Temp\ipykernel_28428\426132078.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include = "all")
#                        Date   Time           Location  Operator Flight #  \
# count                  5268   3049               5248      5250     1069
# unique                 4753   1005               4303      2476      724
# top     2001-09-11 00:00:00  15:00  Sao Paulo, Brazil  Aeroflot        -
# freq                      4     32                 15       179       67
# first   1908-09-17 00:00:00    NaN                NaN       NaN      NaN
# last    2009-06-08 00:00:00    NaN                NaN       NaN      NaN
# mean                    NaN    NaN                NaN       NaN      NaN
# ...

# %%
df["Location"]
# Out:
# 0                                     Fort Myer, Virginia
# 1                                 AtlantiCity, New Jersey
# 2                      Victoria, British Columbia, Canada
# 3                                      Over the North Sea
# 4                              Near Johannisthal, Germany
#                               ...
# 5263                               Near Madiun, Indonesia
# 5264                    Near Isiro, DemocratiRepubliCongo
# 5265    AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266         Near Port Hope Simpson, Newfoundland, Canada
# 5267                    State of Arunachal Pradesh, India
# Name: Location, Length: 5268, dtype: object

# %%
df[["Date","Time"]]
# Out:
#            Date   Time
# 0    1908-09-17  17:18
# 1    1912-07-12  06:30
# 2    1913-08-06    NaN
# 3    1913-09-09  18:30
# 4    1913-10-17  10:30
# ...         ...    ...
# 5263 2009-05-20  06:30
# 5264 2009-05-26    NaN
# 5265 2009-06-01  00:15
# 5266 2009-06-07  08:30
# 5267 2009-06-08    NaN
#
# [5268 rows x 2 columns]

# %%
df["Date"].values
# Out:
# array(['1908-09-17T00:00:00.000000000', '1912-07-12T00:00:00.000000000',
#        '1913-08-06T00:00:00.000000000', ...,
#        '2009-06-01T00:00:00.000000000', '2009-06-07T00:00:00.000000000',
#        '2009-06-08T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df[["Location","Operator"]].value_counts()
# Out:
# Location                       Operator
# Moscow, Russia                 Aeroflot                               9
# Manila, Philippines            Philippine Air Lines                   7
# Kunming, China                 China National Aviation Corporation    6
# Near Moscow, Russia            Aeroflot                               4
# Amsterdam, Netherlands         KLM Royal Dutch Airlines               4
#                                                                      ..
# Lapadrera, Colombia            Interamericana de Aviacion             1
# Landsdowne House, Canada       Austin Airways                         1
# Landrécies, France             KLM Royal Dutch Airlines               1
# Lander, Wyoming                Denver Air Center                      1
# near Orillia, Ontario, Canada  Air Niagara                            1
# Length: 5080, dtype: int64

# %%
df[df["Operator"]=="Aeroflot"]
# Out:
#            Date   Time                       Location  Operator Flight #  \
# 825  1946-12-04    NaN                   Meshed, Iran  Aeroflot      NaN
# 1190 1952-03-26    NaN                 Moscow, Russia  Aeroflot      NaN
# 1273 1953-07-27  12:30      Near Kanggye, North Korea  Aeroflot      NaN
# 1355 1954-12-29    NaN            Near Moscow, Russia  Aeroflot      NaN
# 1356 1954-12-31    NaN                Irkutsk, Russia  Aeroflot      NaN
# ...         ...    ...                            ...       ...      ...
# 4142 1992-10-29    NaN                  Chita, Russia  Aeroflot      NaN
# 4324 1995-03-16    NaN                 Ossora, Russia  Aeroflot      NaN
# 4342 1995-06-16  14:15              Herputchi, Russia  Aeroflot      NaN
# 4445 1996-10-08  10:50  San Francesco al Campo, Italy  Aeroflot     9981
# 5231 2008-09-14  03:15                   Perm, Russia  Aeroflot      821
#
#                              Route              Type Registration  \
# ...

# %%
df[df["Location"]=="Moscow, Russia"]
# Out:
#            Date   Time        Location  \
# 1190 1952-03-26    NaN  Moscow, Russia
# 1684 1960-09-26  23:40  Moscow, Russia
# 2089 1966-12-02    NaN  Moscow, Russia
# 2216 1968-04-22    NaN  Moscow, Russia
# 2335 1969-08-26    NaN  Moscow, Russia
# 2500 1971-10-13    NaN  Moscow, Russia
# 2640 1973-03-03  12:45  Moscow, Russia
# 2696 1973-12-07    NaN  Moscow, Russia
# 2790 1975-01-03    NaN  Moscow, Russia
# 2863 1976-01-03    NaN  Moscow, Russia
# 2941 1976-11-28  19:00  Moscow, Russia
# 4673 1999-12-05  05:12  Moscow, Russia
# 4702 2000-03-09  08:40  Moscow, Russia
# 4876 2002-07-28  15:25  Moscow, Russia
# 5162 2007-07-29  04:22  Moscow, Russia
#
#                                       Operator Flight #  \
# 1190                                  Aeroflot      NaN
# 1684                         Austrian Airlines      901
# 2089                                  Aeroflot      NaN
# 2216                                  Aeroflot      NaN
# ...

# %%
df.sort_values(by='Date', ascending=False)[:20]
# Out:
#            Date   Time                                           Location  \
# 5267 2009-06-08    NaN                  State of Arunachal Pradesh, India
# 5266 2009-06-07  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5265 2009-06-01  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5264 2009-05-26    NaN                  Near Isiro, DemocratiRepubliCongo
# 5263 2009-05-20  06:30                             Near Madiun, Indonesia
# 5262 2009-05-03  12:00                   Near El Alto de Rubio, Venezuela
# 5261 2009-04-29  06:00                 Massamba, DemocratiRepubliof Congo
# 5260 2009-04-17  15:32                   Canaima National Park, Venezuela
# 5259 2009-04-17  10:30                           Mount Gergaji, Indonesia
# 5258 2009-04-09  07:00                             Near Wamena, Indonesia
# 5257 2009-04-06  12:30                                 Bandung, Indonesia
# 5256 2009-04-01  14:00                              Off Crimond, Scotland
# ...

# %%
df.sort_values(by='Date', ascending=True)[:20]
# Out:
#          Date   Time                            Location  \
# 0  1908-09-17  17:18                 Fort Myer, Virginia
# 1  1912-07-12  06:30             AtlantiCity, New Jersey
# 2  1913-08-06    NaN  Victoria, British Columbia, Canada
# 3  1913-09-09  18:30                  Over the North Sea
# 4  1913-10-17  10:30          Near Johannisthal, Germany
# 5  1915-03-05  01:00                     Tienen, Belgium
# 6  1915-09-03  15:20               Off Cuxhaven, Germany
# 7  1916-07-28    NaN               Near Jambol, Bulgeria
# 8  1916-09-24  01:00                 Billericay, England
# 9  1916-10-01  23:45                Potters Bar, England
# 10 1916-11-21    NaN                      Mainz, Germany
# 11 1916-11-28  23:45        Off West Hartlepool, England
# 12 1917-03-04    NaN                  Near Gent, Belgium
# 13 1917-03-30    NaN                Off Northern Germany
# 14 1917-05-14  05:15        Near Texel Island, North Sea
# ...

# %%
df['survival'] = df['Aboard'] - df['Fatalities']

# %%
df.sort_values(by='survival', ascending=False)[:20]
# Out:
#            Date   Time                                Location  \
# 4645 1999-07-23  11:25                            Tokyo, Japan
# 4536 1997-12-28  23:10                    Over the PacifiOcean
# 3640 1986-09-05  06:00                       Karachi, Pakistan
# 3829 1989-02-24  02:09                        Honolulu, Hawaii
# 3378 1982-09-13  12:00                      Near Malaga, Spain
# 4651 1999-08-22  18:45                        Hong Kong, China
# 5057 2005-08-02  16:04                         Toronto, Canada
# 4797 2001-08-24  18:46                        Terceira, Azores
# 4681 1999-12-21  09:40               Guatemala City, Guatemala
# 2720 1974-02-02  21:30                       Near Honolulu, HI
# 4717 2000-05-25    NaN                Near Manila, Philippines
# 4302 1994-12-10  11:30                             PacifiOcean
# 4117 1992-07-30  17:41         JFK Airport, New York, New York
# 3238 1980-12-23  23:12                            Qatar, Qatar
# ...

# %%
df.count() / len(df)
# Out:
# Date            1.000000
# Time            0.578778
# Location        0.996203
# Operator        0.996583
# Flight #        0.202923
# Route           0.676158
# Type            0.994875
# Registration    0.936409
# cn/In           0.766894
# Aboard          0.995824
# Fatalities      0.997722
# Ground          0.995824
# Summary         0.925968
# survival        0.995824
# dtype: float64

# %%
df[df["cn/In"].isna()]
# Out:
#            Date   Time                            Location  \
# 1    1912-07-12  06:30             AtlantiCity, New Jersey
# 2    1913-08-06    NaN  Victoria, British Columbia, Canada
# 3    1913-09-09  18:30                  Over the North Sea
# 4    1913-10-17  10:30          Near Johannisthal, Germany
# 5    1915-03-05  01:00                     Tienen, Belgium
# ...         ...    ...                                 ...
# 5230 2008-09-03  20:20     Off Dubai, United Arab Emirates
# 5249 2009-02-15  16:05                       Chanco, Chile
# 5256 2009-04-01  14:00               Off Crimond, Scotland
# 5262 2009-05-03  12:00    Near El Alto de Rubio, Venezuela
# 5267 2009-06-08    NaN   State of Arunachal Pradesh, India
#
#                          Operator Flight #                    Route  \
# 1            Military - U.S. Navy      NaN              Test flight
# 2                         Private        -                      NaN
# ...

# %%
df[df["cn/In"].isna()].describe(include="all")
# Out:
# C:\Users\soperde\AppData\Local\Temp\ipykernel_28428\3333045686.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df[df["cn/In"].isna()].describe(include="all")
#                        Date   Time      Location  \
# count                  1228    606          1220
# unique                 1193    351          1113
# top     1945-11-11 00:00:00  12:00  AtlantiOcean
# freq                      3     15             7
# first   1912-07-12 00:00:00    NaN           NaN
# last    2009-06-08 00:00:00    NaN           NaN
# mean                    NaN    NaN           NaN
# std                     NaN    NaN           NaN
# min                     NaN    NaN           NaN
# 25%                     NaN    NaN           NaN
# 50%                     NaN    NaN           NaN
# ...

# %%
df[df["Flight #"].isna()]
# Out:
#            Date   Time                                      Location  \
# 0    1908-09-17  17:18                           Fort Myer, Virginia
# 1    1912-07-12  06:30                       AtlantiCity, New Jersey
# 3    1913-09-09  18:30                            Over the North Sea
# 4    1913-10-17  10:30                    Near Johannisthal, Germany
# 5    1915-03-05  01:00                               Tienen, Belgium
# ...         ...    ...                                           ...
# 5262 2009-05-03  12:00              Near El Alto de Rubio, Venezuela
# 5263 2009-05-20  06:30                        Near Madiun, Indonesia
# 5264 2009-05-26    NaN             Near Isiro, DemocratiRepubliCongo
# 5266 2009-06-07  08:30  Near Port Hope Simpson, Newfoundland, Canada
# 5267 2009-06-08    NaN             State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 0                Military - U.S. Army      NaN
# ...

# %%
df[["Location","Operator","Flight #"]].fillna("unknown")
